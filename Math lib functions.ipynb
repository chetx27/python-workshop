# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as pit
sem=[1,2,3,4,5,6,7,8]
marks=[32,33,34,35,36,37,38,39]
pit.plot(sem,marks)
pit.show()
